# %%
#Write a program that takes a string as input, and counts the frequency of each word in the string, there might
#be repeated characters in the string. Your task is to find the highest frequency and returns the length of the
#highest-frequency word.

# %%
def highest_string_freq(stringp):
    list1=stringp.split(' ')
    print('\nlist of all words from the string',list1,'\n')
    list2=[]
    for i in list1:
        if i not in list2:
            list2.append(i)
    print('list of all unique words from the string',list2,'\n') 
    dict={}
    list3=[]
    for i in list2:
        dict[i]=list1.count(i)
        list3.append(list1.count(i))
    print('dictions of words with frequency : ',dict,'\n')    
    maxx=max(list3)
    print(f'highest frequency is : {maxx}','\n')
    count_maxx=list3.count(maxx)
    if count_maxx==1:
        print(f'the is only {count_maxx} element occuring with highest freaquency')
    else:
        print(f'there are {count_maxx} elements occuring with highest freaquency')
    list4=[]    
    for i,j in dict.items():
        if j==3:
            list4.append(i)
        
        
    print('\nthe items with highest frequency in the string are : ',list4)
    for i in range(int(len(list4))):
        print(f'\nthe length of the "{list4[i]}" is\t :   {len(list4[i])}')
 

string1='write write write all the number from from from 1 to 100'
print('For string 1 :\n')
highest_string_freq(string1)
string2='hi hi hi how how are are are you python python python python'
print('\n\n\nfor string 2 :\n')
highest_string_freq(string2)
    
def run():
    repeat=input('\nenter "yes" to run code for another string and "no" for exit\n\n')
    if repeat.lower()=='yes':
        string3=input('\nenter the string\n\n')
        highest_string_freq(string3)
        run()
    else:
        print('\nbye')
        exit()
run()
# Out:
# For string 1 :
#
#
# list of all words from the string ['write', 'write', 'write', 'all', 'the', 'number', 'from', 'from', 'from', '1', 'to', '100']
#
# list of all unique words from the string ['write', 'all', 'the', 'number', 'from', '1', 'to', '100']
#
# dictions of words with frequency :  {'write': 3, 'all': 1, 'the': 1, 'number': 1, 'from': 3, '1': 1, 'to': 1, '100': 1}
#
# highest frequency is : 3
#
# there are 2 elements occuring with highest freaquency
#
# the items with highest frequency in the string are :  ['write', 'from']
#
# the length of the "write" is	 :   5
#
# the length of the "from" is	 :   4
#
#
#
# for string 2 :
#
#
# list of all words from the string ['hi', 'hi', 'hi', 'how', 'how', 'are', 'are', 'are', 'you', 'python', 'python', 'python', 'python']
#
# list of all unique words from the string ['hi', 'how', 'are', 'you', 'python']
#
# dictions of words with frequency :  {'hi': 3, 'how': 2, 'are': 3, 'you': 1, 'python': 4}
#
# highest frequency is : 4
#
# ...
